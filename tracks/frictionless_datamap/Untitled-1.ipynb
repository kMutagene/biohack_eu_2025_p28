# %%
# %pip install arctrl==3.0.0b12
# Out:
# ...
#    ---------------------------------------- 0.0/804.2 kB ? eta -:--:--
#    ---------------------------------------- 804.2/804.2 kB 4.9 MB/s  0:00:00
# ...
#   Attempting uninstall: arctrl
#     Found existing installation: ARCtrl 2.5.1
#     Uninstalling ARCtrl-2.5.1:
#       Successfully uninstalled ARCtrl-2.5.1
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: w:\repos\kMutagene\biohack_eu_2025_p28\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
from arctrl.Core import data_map 

data_map.
