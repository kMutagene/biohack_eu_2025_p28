# %%
// #r "nuget: NGitLab"
#r "nuget: Fshttp"
#r "nuget: dotenv.net"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>dotenv.net, 4.0.0</span></li><li><span>Fshttp, 15.0.3</span></li></ul></div></div>

# %%
open dotenv.net
open System.Text.Json

let envVars = DotEnv.Read();
let token = envVars.["DATAHUB_API_TOKEN"]

# %%
open FsHttp


let all_projects =
    let getResp (page: int) =
        http {
            GET $"https://git.nfdi4plants.org/api/v4/projects"
            query [ "per_page", "100"; "page", string page ]
            headers
                [ 
                    "Authorization", token
                ]
        }
        |> Request.send
        
    let rec loop page (acc: (JsonElement array) list) =
        let response = getResp page

        let items = response |> Response.toJsonArray

        let total_items = 
            response.headers    
            |> Array.ofSeq
            |> Array.tryFind (fun kv -> kv.Key = "X-Total")
            |> Option.bind (fun kv -> if String.IsNullOrEmpty(kv.Value |> Seq.exactlyOne) then None else Some (kv.Value |> Seq.exactlyOne |> int))

        printfn "Fetched page %d with %d items (total items: %A)" page items.Length total_items

        let nextLink =
            response.headers    
            |> Array.ofSeq
            // |> fun x -> printfn "%A" x; x
            |> Array.tryFind (fun kv -> kv.Key = "X-Next-Page")
            |> Option.bind (fun kv -> if String.IsNullOrEmpty(kv.Value |> Seq.exactlyOne) then None else Some (kv.Value |> Seq.exactlyOne |> int))

        printfn "Next link: %A" nextLink

        match nextLink with
        | Some nextPage ->
            loop nextPage (items :: acc)
        | _ -> 
            let allItems =
                acc
                |> List.rev
                |> List.append [ items ]
                |> Array.concat
            allItems
    loop 1 []

all_projects.Length
# Out:
# Fetched page 1 with 100 items (total items: Some 156)
# Next link: Some 2
# Fetched page 2 with 56 items (total items: Some 156)
# Next link: None
# <div class="dni-plaintext"><pre>156</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
open System.Collections.Generic
open System.IO
let saved_files = 
    Directory.GetFiles("./data")
    |> Array.ofSeq
    |> Array.map (fun x -> x.Split("_").[2])

let progress = ResizeArray<string*string>()
let mapperino = Dictionary<string, (string * string * JsonElement array)>()

saved_files
# Out:
# <div class="dni-plaintext"><pre>[ 1000, 1040, 1048, 1050, 1082, 1118, 1222, 1321, 1399, 997 ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
let getTree (repoId: string) =
    let getResp (page: int) =
        http {
            GET $"https://git.nfdi4plants.org/api/v4/projects/{repoId}/repository/tree"
            query [ "per_page", "100"; "recursive", "true"; "page", string page ]
            headers
                [ 
                    "Authorization", token
                ]
        }
        |> Request.send

    let rec loop page (acc: (JsonElement array) list) =
        let response = getResp page

        let items = response |> Response.toJsonArray

        let total_items = 
            response.headers    
            |> Array.ofSeq
            |> Array.tryFind (fun kv -> kv.Key = "X-Total")
            |> Option.bind (fun kv -> if String.IsNullOrEmpty(kv.Value |> Seq.exactlyOne) then None else Some (kv.Value |> Seq.exactlyOne |> int))

        // printfn "Fetched page %d with %d items (total items: %A)" page items.Length total_items

        let nextLink =
            response.headers    
            |> Array.ofSeq
            // |> fun x -> printfn "%A" x; x
            |> Array.tryFind (fun kv -> kv.Key = "X-Next-Page")
            |> Option.bind (fun kv -> if String.IsNullOrEmpty(kv.Value |> Seq.exactlyOne) then None else Some (kv.Value |> Seq.exactlyOne |> int))

        // printfn "Next link: %A" nextLink

        match nextLink with
        | Some nextPage ->
            loop nextPage (items :: acc)
        | _ -> 
            let allItems =
                acc
                |> List.rev
                |> List.append [ items ]
                |> Array.concat
            allItems
    loop 1 []

# %%
let projects_to_skip = ["1842"]

# %%
let all_trees =
    all_projects
    |> Array.iter (fun projectJson ->
        let repoId : string = (projectJson?id).ToString()
        if 
            not (mapperino.ContainsKey(repoId))
            && not (List.contains repoId projects_to_skip)
            && not (Array.contains repoId saved_files)
        then
            printfn "starting repo %A" repoId
            try
                let repoName : string = (projectJson?name).ToString()
                let tree = getTree repoId
                let r = (repoId, repoName, tree |> Array.ofSeq)
                progress.Add(repoId,"done")
                mapperino.Add(repoId, r)
                printfn "Processed repo %s (%s) with %d items" repoName repoId tree.Length
                File.WriteAllText($"data/datahub_repo_{repoId}_tree.json", JsonSerializer.Serialize(tree)) 
                // r
            with ex ->
                progress.Add(repoId, sprintf "error: %s" ex.Message)
                failwithf "Error processing repo %s: %s" repoId ex.Message
        else
            printfn "skipping repo %A" repoId
            // mapperino.[repoId]
    )
# Out:
# skipping repo "1399"
# skipping repo "1321"
# skipping repo "1222"
# skipping repo "1118"
# skipping repo "1082"
# skipping repo "1050"
# skipping repo "1048"
# skipping repo "1040"
# skipping repo "1000"
# skipping repo "997"
# starting repo "984"
# Processed repo Rat MRI + LS (984) with 32406 items
# starting repo "979"
# Processed repo 2023_Krueger_prophage_lysis-lysogeny_MrpR (979) with 100 items
# starting repo "969"
# Processed repo Identification and characterization of DICER-LIKE genes and their roles in Marchantia polymorpha development and salt stress response (969) with 129 items
# starting repo "933"
# Processed repo Samuilov-2018-BOU-PSP (933) with 8542 items
# starting repo "923"
# Processed repo 2022_Krueger_pseudokinase_heme_tolerance (923) with 47 items
# starting repo "897"
# Processed repo MBEN_Resolve (897) with 92 items
# starting repo "784"
# Processed repo Germann-2023 (784) with 133 items
# starting repo "720"
# Processed repo Evolutionary responses to CuZnSODs inhibition in plants 2023 (720) with 265 items
# starting repo "719"
# Processed repo Physcomitrium patens light signaling 2022 (719) with 830 items
# starting repo "692"
# Processed repo Zhu2022JXB (692) with 678 items
# starting repo "663"
# Processed repo BrassicaceaePhotosynthesis2023 (663) with 60 items
# starting repo "658"
# Processed repo Streptomyces-phages (658) with 28 items
# starting repo "625"
# Processed repo Gluconobacter_oxydans_GoxR_Characterization (625) with 103 items
# starting repo "619"
# Processed repo map-by-seq_CLSM-stacks (619) with 366 items
# starting repo "607"
# Processed repo Grow An ARC (607) with 17 items
# starting repo "601"
# Processed repo Molecular plant responses to combined abiotic stresses - Sewelam et al 2020 (601) with 168 items
# starting repo "549"
# Processed repo Solanum_lycopersicoides_RNAsequencing (549) with 118 items
# starting repo "516"
# Processed repo validation_packages_test_index (516) with 9 items
# starting repo "512"
# Processed repo Quinoa_Chileanfieldtrial (512) with 107 items
# starting repo "487"
# Processed repo canal-1 multiomics analysis (487) with 15221 items
# starting repo "482"
# Processed repo Galaxy workflow examples (482) with 2 items
# starting repo "436"
# Processed repo deepSTABp (436) with 939 items
# starting repo "435"
# Processed repo Antifibrotic-effects-of-Oxa (435) with 47 items
# starting repo "434"
# Processed repo Antifibrotic-effects-of-Oxa (434) with 47 items
# starting repo "419"
# Processed repo triesch2023_brassicaceae_transposons (419) with 12694 items
# starting repo "402"
# Processed repo TurboIDSampleArc (402) with 159 items
# starting repo "395"
# Processed repo Talinum fruticosum genome (395) with 60063 items
# starting repo "394"
# Processed repo HeatshockTubercolosisStressitance (394) with 28 items
# starting repo "372"
# Processed repo Triticum (372) with 9 items
# starting repo "355"
# Processed repo ARC_plant_model (355) with 396 items
# starting repo "344"
# Processed repo sampleARC_nfcore (344) with 39 items
# starting repo "342"
# Processed repo deepSTABp (342) with 939 items
# starting repo "339"
# Processed repo ArcPrototype (339) with 89 items
# starting repo "301"
# Processed repo Gotsmann et al 2023 (301) with 2 items
# starting repo "263"
# Processed repo cmQTL_val1_arc (263) with 2198 items
# starting repo "254"
# Processed repo Carbon Availability Transcriptomics Chlamy (254) with 340 items
# starting repo "249"
# Processed repo Metabolights338_ARC (249) with 90 items
# starting repo "151"
# Processed repo CEPLAS RNASeq Workshop 2022 (151) with 240 items
# starting repo "149"
# Processed repo RedoxNetworkTopologyProteomics (149) with 25 items
# starting repo "122"
# Processed repo Ru_ChlamyHeatstress (122) with 627 items
# starting repo "95"
# Processed repo CPN2060_CoIP (95) with 284 items
# starting repo "82"
# Processed repo yeast-structure-proportions (82) with 12113 items
# starting repo "72"
# Processed repo LPA2_ComplexomeProfiling_Chlamy (72) with 2572 items
# starting repo "52"
# Processed repo Wrobel-2023-CastorBeanEndospermProteome (52) with 135 items
# starting repo "31"
# Processed repo Proteomics_Examination (31) with 109 items
# starting repo "16"
# Processed repo samplearc_rnaseq (16) with 44 items
# starting repo "3296"
# Processed repo chromatin_amaranth_2025 (3296) with 39 items
# starting repo "3291"
# Processed repo chromatin_amaranth_2025 (3291) with 39 items
# starting repo "3246"
# Processed repo TomatoHeatMultiOmics-Moneymaker (3246) with 50 items
# starting repo "3219"
# Processed repo Maus_Microbiom (3219) with 633 items
# starting repo "3211"
# Processed repo 10HistoricalPotatoGenomes (3211) with 60 items
# starting repo "3205"
# Processed repo Maus_Microbiom (3205) with 643 items
# starting repo "3204"
# Processed repo Muentjes_et_al-2025 (3204) with 278 items
# starting repo "3171"
# Processed repo DiP FDM Newsletter (3171) with 1 items
# starting repo "3099"
# Processed repo Athaliana_timecourse (3099) with 82 items
# starting repo "3058"
# Processed repo Ru_ChlamyHeatstress (3058) with 627 items
# starting repo "3046"
# Processed repo BreedingValue-Public-Dataset (3046) with 1138 items
# starting repo "3011"
# Processed repo Loo_2025_PBJ (3011) with 127 items
# starting repo "2998"
# Processed repo DAP_Seq (2998) with 20324 items
# starting repo "2986"
# Processed repo DevContainerAndCWL (2986) with 27 items
# starting repo "2974"
# Processed repo LLM_Classifier_Comparison (2974) with 216 items
# starting repo "2972"
# Processed repo Moormann-2025 (2972) with 170 items
# starting repo "2928"
# Processed repo bridge-core50 (2928) with 70 items
# starting repo "2923"
# Processed repo triesch2025_moricandia_snrna_seq (2923) with 8689 items
# starting repo "2905"
# Processed repo Ru_ChlamyHeatstress (2905) with 605 items
# starting repo "2894"
# Processed repo BalancingNutrientRemobilizationAndPhotosynthesis-ProteomicInsightsIntoTheDualRoleOfLupinCotyledonsAfterGermination (2894) with 132 items
# starting repo "2892"
# Processed repo Hasenklever-2024 (2892) with 124 items
# starting repo "2886"
# Processed repo PGAsEffects (2886) with 193 items
# starting repo "2876"
# Processed repo Cold_salt_stress_Capsicum (2876) with 985 items
# starting repo "2862"
# Processed repo Metabolomics_ARC (2862) with 42 items
# starting repo "2860"
# Processed repo Genomics_ARC (2860) with 43 items
# starting repo "2859"
# Processed repo ARC (2859) with 33 items
# starting repo "2847"
# Processed repo Historical_Phenomics_Wheat_Collection_IPK (2847) with 64 items
# starting repo "2844"
# Processed repo QualIQon_Tool (2844) with 1082 items
# starting repo "2745"
# Processed repo NewArc (2745) with 12 items
# starting repo "2693"
# Processed repo 2025_mycorrhization_experiment (2693) with 78 items
# starting repo "2691"
# Processed repo testing-gitlab-access (2691) with 2 items
# starting repo "2684"
# Processed repo Miappe_Showcase_ARC (2684) with 30 items
# starting repo "2650"
# Processed repo Curated_wheat_historical_phenotypic_data_from_European_Genebanks (2650) with 11378 items
# starting repo "2629"
# Processed repo test (2629) with 41 items
# starting repo "2600"
# Processed repo DiP-Ressourcen (2600) with 145 items
# starting repo "2517"
# Processed repo Witting_et_al_Lab_on_chip_2025 (2517) with 518 items
# starting repo "2512"
# Processed repo bund-et-al_2025 (2512) with 39 items
# starting repo "2510"
# Processed repo ARC-Export-TestFixture (2510) with 32 items
# starting repo "2498"
# Processed repo LarvaeDrosophila (2498) with 147 items
# starting repo "2480"
# Processed repo 2025_Expression_System_Adeanei (2480) with 289 items
# starting repo "2405"
# Processed repo Cassava_genome_sequencing_2017 (2405) with 2055 items
# starting repo "2350"
# Processed repo MARS_ENA-Metabolights (2350) with 44 items
# starting repo "2342"
# Processed repo 2025_IronAndHemeRegulatoryNetworks (2342) with 178 items
# starting repo "2294"
# Processed repo 2024_Devan-Sai_et_al_PNAS (2294) with 2180 items
# starting repo "2279"
# Processed repo QualIQon_v1.0 (2279) with 2357 items
# starting repo "2262"
# Processed repo CurtABC_ChlRe_PPI (2262) with 5030 items
# starting repo "2260"
# Processed repo Fe_homeostasis (2260) with 88 items
# starting repo "2225"
# Processed repo Schladt et al. 2024 - NUPs (2225) with 3196 items
# starting repo "2222"
# Processed repo Chitinase_RE_2024_2 (2222) with 120 items
# starting repo "2214"
# Processed repo Bagshaw_et_al_HXK1_CHUP1 (2214) with 67 items
# starting repo "2188"
# Processed repo Schladt et al. 2024 - NUPs (2188) with 3196 items
# starting repo "2180"
# Processed repo Getzke-2023 (2180) with 51 items
# starting repo "2166"
# Processed repo Helmsorig-2024-eam7 (2166) with 227 items
# starting repo "2164"
# Processed repo AthalianaColdStressSugar (2164) with 70 items
# starting repo "2142"
# Processed repo ArcPrototype-test (2142) with 79 items
# starting repo "2012"
# Processed repo gitlab-profile (2012) with 2 items
# starting repo "1978"
# Processed repo Guichard-2024 (1978) with 107 items
# starting repo "1976"
# Processed repo CPlantBox_Simulations (1976) with 397 items
# starting repo "1949"
# Processed repo Helmsorig-2024-eam7 (1949) with 225 items
# starting repo "1940"
# Processed repo betalain_regulation_amaranth (1940) with 298 items
# starting repo "1934"
# Processed repo N_glauca_analysis (1934) with 6 items
# starting repo "1933"
# Processed repo Solanum_lycopersicoides_RNAsequencing (1933) with 118 items
# starting repo "1932"
# Processed repo Camellia_sinensis_genomics (1932) with 200 items
# starting repo "1931"
# Processed repo Quinoa_Chileanfieldtrial (1931) with 60 items
# starting repo "1910"
# Processed repo Chitinase_RE_2024_2 (1910) with 120 items
# starting repo "1873"
# Processed repo Wrobel-2023-CastorBeanEndospermProteome (1873) with 135 items
# starting repo "1872"
# Processed repo VonDahlen-2023 (1872) with 162 items
# starting repo "1871"
# Processed repo Getzke-2023 (1871) with 19 items
# starting repo "1870"
# Processed repo Wippel-2021 (1870) with 1971 items
# starting repo "1868"
# Processed repo Gao-2024 (1868) with 83 items
# starting repo "1863"
# Processed repo Kindel-2024 (1863) with 78 items
# starting repo "1862"
# Processed repo Wanke-2021 (1862) with 20 items
# starting repo "1861"
# Processed repo BrassicaceaePhotosynthesis2023 (1861) with 60 items
# starting repo "1858"
# Processed repo DeJager-2024 (1858) with 103 items
# starting repo "1857"
# Processed repo FokoKuate-2023 (1857) with 18 items
# starting repo "1856"
# Processed repo Chandrasekar-2022 (1856) with 72 items
# starting repo "1853"
# Processed repo betalain_regulation_amaranth (1853) with 298 items
# starting repo "1851"
# Processed repo Loo-2024 (1851) with 212 items
# skipping repo "1842"
# starting repo "1821"
# Processed repo CPlantBox_Simulations (1821) with 397 items
# starting repo "1812"
# Processed repo Jet Datasets (1812) with 510 items
# starting repo "1709"
# Processed repo JHI Barley Trial (1709) with 27 items
# starting repo "1701"
# Processed repo JHI Test Data (1701) with 17 items
# starting repo "1678"
# Processed repo Test Template (1678) with 41 items
# starting repo "1664"
# Processed repo OMICS_DB (1664) with 79 items
# starting repo "1641"
# Processed repo 2024_Kitashova_et_al_subcellular (1641) with 3521 items
# starting repo "1627"
# Processed repo Subcellular_analysis_of_metabolic_network_dynamics_under_elevated_CO2 (1627) with 3988 items
# starting repo "1621"
# Processed repo Ru_ChlamyHeatstress (1621) with 576 items
# starting repo "1605"
# Processed repo ProteinAndAminoAcidMetabolismDuringLupinGermination (1605) with 113 items
# starting repo "1590"
# Processed repo Lan_2025_Ppd-H1 (1590) with 4117 items
# starting repo "1582"
# Processed repo 2024_GrowthCoupledHemeBiosensor (1582) with 63 items
# starting repo "1536"
# Processed repo LFSLargeFilesUploadTest3 (1536) with 47 items
# starting repo "1488"
# Processed repo Ribes_nigrum_genome (1488) with 101 items
# starting repo "1487"
# Processed repo 2024_Kitashova_et_al_subcellular (1487) with 1323 items
# starting repo "1455"
# Processed repo Camellia_sinensis_genomics (1455) with 194 items
# starting repo "1447"
# Processed repo MibiNet_Data_Showcases (1447) with 170 items
# starting repo "1427"
# Processed repo Shape (1427) with 74 items
# starting repo "1425"
# Processed repo ArcPrototype (1425) with 80 items
# starting repo "1419"
# Processed repo Lucas_Mueller_PhD_ARC (1419) with 17 items
# starting repo "1402"
# Processed repo NGSAppetizerCourse (1402) with 108 items

# %%
progress

# %%
all_trees.Length

# %%
let filterXLSX (tree: JsonElement array) = 
    tree
    |> Array.ofSeq
    |> Array.filter (fun x -> 
        let path = (x?path).ToString()  
        path.EndsWith(".xlsx")
        && not (path.Contains("isa.investigation.xlsx"))
        && not (path.Contains("isa.assay.xlsx"))
        && not (path.Contains("isa.study.xlsx"))
    )

# %%
all_trees
|> Array.map (fun (repoId, tree) ->
    repoId,
    filterXLSX tree
    |> Array.map (fun x -> x?path.ToString())
)
|> Array.filter (fun (_, paths) -> paths.Length > 0)
|> Map.ofArray

# %%
all_trees
|> Array.map (fun (repoId, tree) ->
    repoId,
    tree
    |> Array.iter (fun itemJson ->
        let itemName : string = (itemJson?name).ToString()
        printfn " - %s" itemName
    )
)

# %%
let all_visible_projects = 
    client.Projects.GetAsync()
    |> Async.AwaitTask
    |> Async.RunSynchronously
    |> Array.ofSeq

# %%
all_visible_projects[0].Id

# %%
client.Projects.

# %%
client.

# %%
all_visible_projects
|> Array.map (fun project ->
    project.
)
